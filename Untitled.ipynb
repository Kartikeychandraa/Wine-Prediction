# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
wine = pd.read_csv("winedata.csv")

# %%
wine.isnull().sum() # check null values
# Out:
# fixed.acidity           0
# volatile.acidity        0
# citric.acid             0
# residual.sugar          0
# chlorides               0
# free.sulfur.dioxide     0
# total.sulfur.dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# id                      0
# dtype: int64

# %%
wine.describe(include="all") #visual on all
# Out:
#        fixed.acidity  volatile.acidity  citric.acid  residual.sugar  \
# count    3918.000000       3918.000000  3918.000000     3918.000000
# mean        6.854620          0.278027     0.333201        6.405819
# std         0.841879          0.100459     0.121375        5.107972
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.310000        5.200000
# 75%         7.300000          0.320000     0.380000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free.sulfur.dioxide  total.sulfur.dioxide      density  \
# count  3918.000000          3918.000000           3918.000000  3918.000000
# mean      0.045566            35.326187            138.395227     0.994026
# std       0.021138            17.158043             42.996820     0.003025
# ...

# %%
fig,axes=plt.subplots(5,5)
columns=['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
       'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
       'pH', 'sulphates', 'alcohol', 'quality']
        axes[5,5].hist(x=columns[5+5],data=df,edgecolor='#000000',linewidth=2,color='#ff4125')
        axes[5,5].set_title('Variation of '+columns[5+5])
fig=plt.gcf()
fig.set_size_inches(18,18)
fig.tight_layout()
# Out:
#   File "<ipython-input-11-cd1e1249c14b>", line 5
#     axes[5,5].hist(x=columns[5+5],data=df,edgecolor='#000000',linewidth=2,color='#ff4125')
#     ^
# IndentationError: unexpected indent
